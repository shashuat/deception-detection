# %%
import os

dir_path = "/Data/dec/data/downloaded/"
num_files = len([f for f in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, f))])

print(f"Number of files in {dir_path}: {num_files}")

# %%
import os

dir_path = "/Data/dec/data/audio_files"
num_files = len([f for f in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, f))])

print(f"Number of files in {dir_path}: {num_files}")

# %%
from plots import plot_logs

log_path = "../../logs/1742770598_DOLOS_layers_4_Adapter_True_type_efficient_conv_multi.json"
plot_logs(log_path, title="Whisper tokens faces ViT with cross2 modal concat - Loss & accuracy evolution")
